# %% [markdown]
# # Removed (cases and deaths) accumulated per day per city

# %%
import dask.dataframe as dd
import pandas as pd

dataset_size = 'full'
all_data_path = './../data/rem/'
data_path = f'./../data/rem/{dataset_size}/'

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# /home/jedi/.pyenv/37venv/lib/python3.7/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34349 instead
#   f"Port {expected} is already in use.\n"
# <Client: 'tcp://127.0.0.1:37633' processes=4 threads=12, memory=15.63 GiB>

# %% [markdown]
# ## Criando um arquivo menor para testes

# %%
small_data_path = f'{all_data_path}/small/brazil_covid19_cities.csv'
full_data_path = f'{all_data_path}/full/brazil_covid19_cities.csv'

# shell magic
![ -f "{small_data_path}" ] || (head -n 12500 "{full_data_path}" > "{small_data_path}")

# %%
# TODO make simple per day, per city cases and deaths

ddf = dd.read_csv(f'{data_path}/brazil_covid19_cities.csv',
    sep=',',
    dtype={})

ddf.head()
# Out:
#          date state          name      code  cases  deaths
# 0  2020-03-27    AC    Acrelândia  120001.0    0.0       0
# 1  2020-03-27    AC  Assis Brasil  120005.0    0.0       0
# 2  2020-03-27    AC     Brasiléia  120010.0    0.0       0
# 3  2020-03-27    AC        Bujari  120013.0    0.0       0
# 4  2020-03-27    AC      Capixaba  120017.0    0.0       0

# %%
ddf = ddf[ddf['state'] == 'PR']

print('saving removeds')
ddf.to_csv(f'{data_path}/removed_parana.csv', single_file=True, index=False)
# Out:
# saving removeds
# ['/home/jedi/git-repos/CD Covid Project/data/rem/full/removed_parana.csv']
