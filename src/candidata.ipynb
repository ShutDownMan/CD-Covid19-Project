# %%
# https://github.com/candidata/candidata_dataset/blob/main/data/2018/votacao_candidato_munzona_2018_PR.csv
import pandas as pd

dataset_size = 'full'

all_data_path = './../data/candidata/'
data_path = f'./../data/candidata/{dataset_size}/'

# %%
# read parana's social info by municipality

can_df = pd.read_csv(f'{data_path}/candidata_parana.csv',
    sep=',',
    dtype={}
)

# can_df = can_df[['NM_CANDIDATO', 'NR_PARTIDO', 'SQ_COLIGACAO', 'NM_COLIGACAO', 'CD_MUNICIPIO']]

can_df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  08/08/2021   11:00:47         2018                2  ELEICAO ORDINARIA
# 1  08/08/2021   11:00:47         2018                2  ELEICAO ORDINARIA
# 2  08/08/2021   11:00:47         2018                2  ELEICAO ORDINARIA
# 3  08/08/2021   11:00:47         2018                2  ELEICAO ORDINARIA
# 4  08/08/2021   11:00:47         2018                2  ELEICAO ORDINARIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         297  Eleicoes Gerais Estaduais 2018  07/10/2018
# 1         1         297  Eleicoes Gerais Estaduais 2018  07/10/2018
# 2         1         297  Eleicoes Gerais Estaduais 2018  07/10/2018
# 3         1         297  Eleicoes Gerais Estaduais 2018  07/10/2018
# 4         1         297  Eleicoes Gerais Estaduais 2018  07/10/2018
#
#   TP_ABRANGENCIA  ... CD_OCUPACAO                DS_OCUPACAO CD_SIT_TOT_TURNO  \
# ...
